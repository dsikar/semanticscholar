# %% [markdown]
# # IJCAI 2017 Word Clouds

# %%
# import library
import sys
sys.path.append('../src/')
from helper_functions import getInfo, getAllInfo, wcloud

# %%
# IJCAI 2017 DOI suffix, we need to do it from 1 to 781
# first
# https://doi.org/10.24963/ijcai.2017/1 
# last
# https://doi.org/10.24963/ijcai.2017/781 
suffix = '10.24963/ijcai.2017/'
# ALL INFO
start = 1
end = 781
IJCAI2017papers = []
IJCAI2017papers = getAllInfo(suffix, start, end)
# Out:
# Found paper DOI: 10.24963/ijcai.2017/1
# Found paper DOI: 10.24963/ijcai.2017/2
# Found paper DOI: 10.24963/ijcai.2017/3
# Found paper DOI: 10.24963/ijcai.2017/4
# Found paper DOI: 10.24963/ijcai.2017/5
# Found paper DOI: 10.24963/ijcai.2017/6
# Found paper DOI: 10.24963/ijcai.2017/7
# Found paper DOI: 10.24963/ijcai.2017/8
# Found paper DOI: 10.24963/ijcai.2017/9
# Found paper DOI: 10.24963/ijcai.2017/10
# Found paper DOI: 10.24963/ijcai.2017/11
# Found paper DOI: 10.24963/ijcai.2017/12
# Found paper DOI: 10.24963/ijcai.2017/13
# Found paper DOI: 10.24963/ijcai.2017/14
# Found paper DOI: 10.24963/ijcai.2017/15
# Found paper DOI: 10.24963/ijcai.2017/16
# Found paper DOI: 10.24963/ijcai.2017/17
# Found paper DOI: 10.24963/ijcai.2017/18
# Found paper DOI: 10.24963/ijcai.2017/19
# Found paper DOI: 10.24963/ijcai.2017/20
# Found paper DOI: 10.24963/ijcai.2017/21
# Found paper DOI: 10.24963/ijcai.2017/22
# Found paper DOI: 10.24963/ijcai.2017/23
# Found paper DOI: 10.24963/ijcai.2017/24
# ...

# %%
import json
with open('IJCAI2017papers.json', 'w') as f:
    json.dump(IJCAI2017papers, f)

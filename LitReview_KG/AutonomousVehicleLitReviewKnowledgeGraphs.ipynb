# %% [markdown]
# # Autonomous Vehicle Literature Review Knowledge Graphs
# Investigation on Knowledge Graphs assisting literature reviews.
# Using API https://www.semanticscholar.org/product/api via semanticscholar python module.
# and noting for future reference that AI2 has an open source PyTorch NLP research library:
# https://github.com/allenai/allennlp

# %%
# Some modified boilerplate code, previously we had worked with a subset
# of dictionary keys, here we will use all to start with

# helper functions for ML/AI applied to literature review
def getInfo(suffix, start, end, key) :
    """
    Get AI2 Semantic Scholar article info
    Inputs
        suffix: string, DOI suffix
        start: integer, first paper index
        end: integer, last paper index
        key: dictionary key
    Examples:
    # SAFECOMP 2020 get all 31 abstracts
    text = getInfo('10.1007/978-3-030-55583-2_', 1, 31, 'abstract')
    all keys:
    'abstract', 'arxivId', 'authors', 'citationVelocity', 'citations', 'corpusId', 'doi', 'fieldsOfStudy',
    'influentialCitationCount', 'isOpenAccess', 'isPublisherLicensed', 'is_open_access', 'is_publisher_licensed',
    'numCitedBy', 'numCiting', 'paperId', 'references', 'title', 'topics', 'url', 'venue', 'year'
    """
    import time
    import semanticscholar as sch 
    text = ''
    for i in range (start,end+1) :
        doi = suffix + str(i)
        paper = sch.paper(doi, timeout=2)
        if key in paper :
            text = text + paper[key] + ' '
        else :
            print('No {} for paper index {}'.format(key, i))
            print("DOI entry: ", doi)
        time.sleep(3)
    return text

def getAllInfo(suffix, start, end) :
    """
    Get AI2/DOI Semantic Scholar complete article info
    Inputs
        suffix: string, DOI suffix
        start: integer, first paper index
        end: integer, last paper index
    Output
        papers: list of dictionaries
    Examples:    
    # SAFECOMP 2020 get all 31 papers
    text = getInfo('10.1007/978-3-030-55583-2_', 1, 31, 'abstract')  
    all keys:
    'abstract', 'arxivId', 'authors', 'citationVelocity', 'citations', 'corpusId', 'doi', 'fieldsOfStudy', 
    'influentialCitationCount', 'isOpenAccess', 'isPublisherLicensed', 'is_open_access', 'is_publisher_licensed', 
    'numCitedBy', 'numCiting', 'paperId', 'references', 'title', 'topics', 'url', 'venue', 'year'
    """
    import time
    import semanticscholar as sch 
    papers = []
    for i in range (start,end+1) :
        doi = suffix + str(i)
        paper = sch.paper(doi, timeout=2)
        if 'abstract' in paper :
            print('Found paper DOI:', doi)
            papers.append(paper)
        else :
            print('No abstract for paper index {}'.format(i))
            print("DOI entry: ", doi)
        # pause 3 seconds to stop Semantic Scholar from blocking automated searches (repeating
        # in intervals less than 3 seconds long)
        time.sleep(3)
    return papers

# %%
# does "title" search work?
import semanticscholar as sch
title = "An Auto-tuning Framework for Autonomous Vehicles"
results = sch.paper(title, timeout=2)
len(results) # 0
# User corpus ID
title = "52013502"
results = sch.paper(title, timeout=2)
len(results) # 0
# Out:
# 0

# %%
# cannot run wget from notebook
# !wget https://api.semanticscholar.org/v1/paper/CorpusID:52013502 -o baidu.txt
# Out:
# /bin/sh: 1: wget: not found

# %%
# AirSim paper
# https://www.semanticscholar.org/paper/a20f3dfc9142b48b924e68ee22ba259a0d621bb2
# S2 (semantic scholar) Paper ID - this works
title = "a20f3dfc9142b48b924e68ee22ba259a0d621bb2"
results = sch.paper(title, timeout=2)
print(len(results)) # 22
for key in results :
    print(key)
# Out:
# 22
# abstract
# arxivId
# authors
# citationVelocity
# citations
# corpusId
# doi
# fieldsOfStudy
# influentialCitationCount
# isOpenAccess
# isPublisherLicensed
# is_open_access
# is_publisher_licensed
# numCitedBy
# numCiting
# paperId
# references
# title
# topics
# url
# venue
# year

# %% [markdown]
# ## Using S2 (Semantic Scholar) Paper ID
# We use Paper ID to retrieve information for our 4 papers

# %%
# paper ids - extracted from url, by searching article title at
# https://www.semanticscholar.org/
pids = ['a20f3dfc9142b48b924e68ee22ba259a0d621bb2', # airsim
        '4592a123502a9e7bbd76d21c976a4ed17503df8c', # baidu apollo
        '1b7ef1a7df32d8d38efbb7aca9a9b2468d0da224', # carla
        '65b58efdd4c04bb501244a8f825b28dcba788b60'] # LGSVL

# %%
# Let's use a dictionary
pids = {'airsim' : 'a20f3dfc9142b48b924e68ee22ba259a0d621bb2', # airsim
        'baidu' : '4592a123502a9e7bbd76d21c976a4ed17503df8c', # baidu apollo
        'carla' : '1b7ef1a7df32d8d38efbb7aca9a9b2468d0da224', # carla
        'LGSVL' : '65b58efdd4c04bb501244a8f825b28dcba788b60'} # LGSVL

# %%
for key in pids :
    print(pids[key])
# Out:
# a20f3dfc9142b48b924e68ee22ba259a0d621bb2
# 4592a123502a9e7bbd76d21c976a4ed17503df8c
# 1b7ef1a7df32d8d38efbb7aca9a9b2468d0da224
# 65b58efdd4c04bb501244a8f825b28dcba788b60

# %%
# retrieve data
def AI2PIDsearch(pid):
    """
    Search AI2 by paper ID
    Input:
        pid: string, AI2 paper ID
    Output
        paper: dictionary
    Example:
    paper = AI2PIDsearch('a20f3dfc9142b48b924e68ee22ba259a0d621bb2')
    print(paper['title'])
    AirSim: High-Fidelity Visual and Physical Simulation for Autonomous Vehicles
    """
    import semanticscholar as sch
    import time
    results = sch.paper(pid, timeout=2)
    time.sleep(3) # do not hammer AI2
    return results

# %%
# init results dictionary
results = {}
for key in pids :
    result = AI2PIDsearch(pids[key])
    results[key] = result

# %%
for key in results :
    print(len(results[key]))
# Out:
# 22
# 22
# 22
# 22

# %%
# build graph:
# we are looking at
# https://www.stardog.com/tutorials/sparql/
# https://github.com/stardog-union/stardog-tutorials/blob/master/music/beatles.ttl
# https://github.com/city-knowledge-graphs/python/blob/main/lab4/lab4.ttl
"""
@prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
@prefix : <http://city.ac.uk/kg/lab4/> .

:airsim       rdf:type  :Article .
:airsim       :title    "<topics>" .
:airsim       :topic    "<topics>" .
:airsim       :citation "<citations>" .
"""
# Out:
# 'AirSim: High-Fidelity Visual and Physical Simulation for Autonomous Vehicles'

# %%
#for key in results :
#    print(key)
#airsim
#baidu
#carla
#LGSVL
for key in results['airsim'] :
    print(key)
    
abstract
arxivId
authors
citationVelocity
citations
corpusId
doi
fieldsOfStudy
influentialCitationCount
isOpenAccess
isPublisherLicensed
is_open_access
is_publisher_licensed
numCitedBy
numCiting
paperId
references
title
topics
url
venue
year
# Out:
# abstract
# arxivId
# authors
# citationVelocity
# citations
# corpusId
# doi
# fieldsOfStudy
# influentialCitationCount
# isOpenAccess
# isPublisherLicensed
# is_open_access
# is_publisher_licensed
# numCitedBy
# numCiting
# paperId
# references
# title
# topics
# url
# venue
# year

# %%
# print header
header = """
@prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
@prefix : <http://city.ac.uk/kg/lab4/> .

"""
print(header)

# iterate through dictionary
for key in results:
    # rdf:type
    print(":{}		rdf:type	:Article .".format(key))
    print(":{}		:title		\"{}\" .".format(key, results[key]['title']))
    for topic in results[key]['topics'] :
        print(":{}		:topic		\"{}\" .".format(key, topic['topic']))
    for reference in results[key]['references'] :
        print(":{}		:citation	\"{}\" .".format(key, reference['title']))
# Out:
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix : <http://city.ac.uk/kg/lab4/> .
#
#
# :airsim		rdf:type	:Article .
# :airsim		:title		"AirSim: High-Fidelity Visual and Physical Simulation for Autonomous Vehicles" .
# :airsim		:topic		"Autonomous robot" .
# :airsim		:topic		"Physics engine" .
# :airsim		:topic		"Unreal Development Kit" .
# :airsim		:topic		"PhysX" .
# :airsim		:topic		"Machine learning" .
# :airsim		:topic		"Reinforcement learning" .
# :airsim		:topic		"Ray tracing (graphics)" .
# :airsim		:topic		"Deep learning" .
# :airsim		:topic		"Extensibility" .
# :airsim		:topic		"Artificial intelligence" .
# :airsim		:topic		"Modular design" .
# :airsim		:topic		"Algorithm" .
# :airsim		:topic		"Augmented reality" .
# :airsim		:topic		"Hardware-in-the-loop simulation" .
# :airsim		:topic		"Component-based software engineering" .
# :airsim		:topic		"Experiment" .
# :airsim		:topic		"Sensor" .
# :airsim		:topic		"Real-time clock" .
# :airsim		:topic		"Application programming interface" .
# :airsim		:topic		"Global Positioning System" .
# :airsim		:topic		"Elegant degradation" .
# :airsim		:topic		"Stepping level" .
# :airsim		:topic		"MAVLink" .
# :airsim		:topic		"Real-time operating system" .
# :airsim		:topic		"Dynamical simulation" .
# :airsim		:citation	"Classical mechanics" .
# :airsim		:citation	"Introduction to fluid mechanics" .
# :airsim		:citation	"History of fluid mechanics" .
# :airsim		:citation	"Numerical methods for ordinary differential equations" .
# :airsim		:citation	"Design and use paradigms for Gazebo, an open-source multi-robot simulator" .
# :airsim		:citation	"The GGM03 Mean Earth Gravity Model from GRACE" .
# :airsim		:citation	"The Earth's Magnetism: An Introduction for Geologists" .
# :airsim		:citation	"An introduction to inertial navigation" .
# :airsim		:citation	"PIXHAWK: A system for autonomous flight using onboard computer vision" .
# :airsim		:citation	"Comprehensive Simulation of Quadrotor UAVs Using ROS and Gazebo" .
# :airsim		:citation	"Numerical Methods for Ordinary Differential Equations" .
# :airsim		:citation	"A survey of inverse reinforcement learning techniques" .
# :airsim		:citation	"A survey of inverse reinforcement learning techniques" .
# :airsim		:citation	"Reinforcement learning in robotics: A survey" .
# :airsim		:citation	"Real Shading in Unreal Engine 4 by" .
# :airsim		:citation	"A Stochastic Approach to Noise Modeling for Barometric Altimeters" .
# :airsim		:citation	"An Invitation to Imitation" .
# :airsim		:citation	"The US/UK World Magnetic Model for 2015-2020" .
# :airsim		:citation	"RotorS—A Modular Gazebo MAV Simulator Framework" .
# :airsim		:citation	"ROSflight: A lightweight, inexpensive MAV research and development tool" .
# :airsim		:citation	"Practical Meteorology: An Algebra-based Survey of Atmospheric Science" .
# :airsim		:citation	"A survey of transfer learning" .
# :airsim		:citation	"A First Course In Differential Equations" .
# :baidu		rdf:type	:Article .
# :baidu		:title		"An Auto-tuning Framework for Autonomous Vehicles" .
# :baidu		:topic		"Reinforcement learning" .
# :baidu		:topic		"Autonomous car" .
# :baidu		:topic		"Autonomous robot" .
# :baidu		:topic		"Simulation" .
# :baidu		:topic		"Mathematical optimization" .
# :baidu		:topic		"Self-tuning" .
# :baidu		:topic		"Algorithm" .
# :baidu		:topic		"Corner case" .
# :baidu		:topic		"Feature extraction" .
# :baidu		:topic		"Loss function" .
# :baidu		:topic		"Online and offline" .
# :baidu		:topic		"Machine learning" .
# :baidu		:topic		"Procedural generation" .
# :baidu		:topic		"Value network" .
# :baidu		:topic		"Long tail" .
# :baidu		:topic		"Scalability" .
# :baidu		:topic		"Tracer" .
# :baidu		:topic		"Auto-Tune" .
# :baidu		:topic		"Drug vehicle" .
# :baidu		:citation	"Efficient Training of Artificial Neural Networks for Autonomous Navigation" .
# :baidu		:citation	"Algorithms for Inverse Reinforcement Learning" .
# :baidu		:citation	"Proceedings of the twenty-first international conference on Machine learning" .
# :baidu		:citation	"Apprenticeship learning via inverse reinforcement learning" .
# :baidu		:citation	"Learning a similarity metric discriminatively, with application to face verification" .
# :baidu		:citation	"Maximum margin planning" .
# :baidu		:citation	"Maximum Entropy Inverse Reinforcement Learning" .
# :baidu		:citation	"Autonomous Driving in Urban Environments: Boss and the Urban Challenge" .
# :baidu		:citation	"Junior: The Stanford Entry in the Urban Challenge" .
# :baidu		:citation	"Optimal trajectory generation for dynamic street scenarios in a Frenét Frame" .
# :baidu		:citation	"Efficient Reductions for Imitation Learning" .
# :baidu		:citation	"A Reduction of Imitation Learning and Structured Prediction to No-Regret Online Learning" .
# :baidu		:citation	"Trajectory planning for Bertha — A local, continuous method" .
# :baidu		:citation	"End to End Learning for Self-Driving Cars" .
# :baidu		:citation	"A Fast Integrated Planning and Control Framework for Autonomous Driving via Imitation Learning" .
# :baidu		:citation	"Baidu Apollo EM Motion Planner" .
# :carla		rdf:type	:Article .
# :carla		:title		"CARLA: An Open Urban Driving Simulator" .
# :carla		:topic		"Driving simulator" .
# :carla		:topic		"Reinforcement learning" .
# :carla		:topic		"Autonomous car" .
# :carla		:topic		"Open-source software" .
# :carla		:topic		"Autonomous robot" .
# :carla		:topic		"Digital asset" .
# :carla		:topic		"Simulation" .
# :carla		:topic		"End-to-end principle" .
# :carla		:citation	"ALVINN: An Autonomous Land Vehicle in a Neural Network" .
# :carla		:citation	"Off-Road Obstacle Avoidance through End-to-End Learning" .
# :carla		:citation	"Learning from Demonstration for Autonomous Navigation in Complex Unstructured Terrain" .
# :carla		:citation	"Real-Time Camera Tracking: When is High Frame-Rate Best?" .
# :carla		:citation	"ImageNet classification with deep convolutional neural networks" .
# :carla		:citation	"Framework for Generation of Synthetic Ground Truth Data for Driver Assistance Applications" .
# :carla		:citation	"Robust PID Steering Control in Parameter Space for Highly Automated Driving" .
# :carla		:citation	"Adam: A Method for Stochastic Optimization" .
# :carla		:citation	"DeepDriving: Learning Affordance for Direct Perception in Autonomous Driving" .
# :carla		:citation	"Human-level control through deep reinforcement learning" .
# :carla		:citation	"Autonomous driving" .
# :carla		:citation	"High-fidelity simulation for evaluating robotic vision performance" .
# :carla		:citation	"A Benchmark and Simulator for UAV Tracking" .
# :carla		:citation	"Evaluating visual ADAS components on the COnGRATS dataset" .
# :carla		:citation	"Playing for Data: Ground Truth from Computer Games" .
# :carla		:citation	"Asynchronous Methods for Deep Reinforcement Learning" .
# :carla		:citation	"A Survey of Motion Planning and Control Techniques for Self-Driving Urban Vehicles" .
# :carla		:citation	"The SYNTHIA Dataset: A Large Collection of Synthetic Images for Semantic Segmentation of Urban Scenes" .
# :carla		:citation	"VirtualWorlds as Proxy for Multi-object Tracking Analysis" .
# :carla		:citation	"Benefit of large field-of-view cameras for visual odometry" .
# :carla		:citation	"Learning to Act by Predicting the Future" .
# :carla		:citation	"AutonoVi: Autonomous vehicle planning with dynamic maneuvers and traffic constraints" .
# :carla		:citation	"Playing for Benchmarks" .
# :carla		:citation	"Reinforcement Learning with Unsupervised Auxiliary Tasks" .
# :carla		:citation	"RefineNet: Multi-path Refinement Networks for High-Resolution Semantic Segmentation" .
# :carla		:citation	"Deep Reinforcement Learning that Matters" .
# :carla		:citation	"End-to-End Driving Via Conditional Imitation Learning" .
# :LGSVL		rdf:type	:Article .
# :LGSVL		:title		"LGSVL Simulator: A High Fidelity Simulator for Autonomous Driving" .
# :LGSVL		:topic		"Autonomous car" .
# :LGSVL		:topic		"Simulation" .
# :LGSVL		:topic		"Autonomous robot" .
# :LGSVL		:topic		"Open-source software" .
# :LGSVL		:topic		"Sensor" .
# :LGSVL		:topic		"End-to-end principle" .
# :LGSVL		:topic		"Algorithm" .
# :LGSVL		:citation	"ALVINN: An Autonomous Land Vehicle in a Neural Network" .
# :LGSVL		:citation	"Design and use paradigms for Gazebo, an open-source multi-robot simulator" .
# :LGSVL		:citation	"TORCS, The Open Racing Car Simulator" .
# :LGSVL		:citation	"Vision meets robotics: The KITTI dataset" .
# :LGSVL		:citation	"DeepDriving: Learning Affordance for Direct Perception in Autonomous Driving" .
# :LGSVL		:citation	"Playing for Data: Ground Truth from Computer Games" .
# :LGSVL		:citation	"Driving to safety: How many miles of driving would it take to demonstrate autonomous vehicle reliability?" .
# :LGSVL		:citation	"The Cityscapes Dataset for Semantic Urban Scene Understanding" .
# :LGSVL		:citation	"OpenAI Gym" .
# :LGSVL		:citation	"CARLA: An Open Urban Driving Simulator" .
# :LGSVL		:citation	"Driving in the Matrix: Can virtual worlds replace human-generated annotations for real world tasks?" .
# :LGSVL		:citation	"Playing for Benchmarks" .
# :LGSVL		:citation	"AirSim: High-Fidelity Visual and Physical Simulation for Autonomous Vehicles" .
# :LGSVL		:citation	"BDD100K: A Diverse Driving Video Database with Scalable Annotation Tooling" .
# :LGSVL		:citation	"Lanelet2: A high-definition map framework for the future of automated driving" .
# :LGSVL		:citation	"Cooperative Ramp Merging System: Agent-Based Modeling and Simulation Using Game Engine" .
# :LGSVL		:citation	"Scenic: a language for scenario specification and scene generation" .
# :LGSVL		:citation	"Scalability in Perception for Autonomous Driving: Waymo Open Dataset" .
# :LGSVL		:citation	"nuScenes: A Multimodal Dataset for Autonomous Driving" .
# :LGSVL		:citation	"Formal Scenario-Based Testing of Autonomous Vehicles: From Simulation to the Real World" .

# %%
# print header
header = """
@prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
@prefix : <http://city.ac.uk/kg/lab4/> .

"""
ttl = header + "\n"

# iterate through dictionary
for key in results:
    # rdf:type
    ttl += ":{}		rdf:type	:Article .\n".format(key)
    ttl += ":{}		:title		\"{}\" .\n".format(key, results[key]['title'])
    for topic in results[key]['topics'] :
        ttl += ":{}		:topic		\"{}\" .\n".format(key, topic['topic'])
    for reference in results[key]['references'] :
        ttl += ":{}		:citation	\"{}\" .\n".format(key, reference['title'])
print(ttl)
# Out:
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix : <http://city.ac.uk/kg/lab4/> .
#
#
# :airsim		rdf:type	:Article .
# :airsim		:title		"AirSim: High-Fidelity Visual and Physical Simulation for Autonomous Vehicles" .
# :airsim		:topic		"Autonomous robot" .
# :airsim		:topic		"Physics engine" .
# :airsim		:topic		"Unreal Development Kit" .
# :airsim		:topic		"PhysX" .
# :airsim		:topic		"Machine learning" .
# :airsim		:topic		"Reinforcement learning" .
# :airsim		:topic		"Ray tracing (graphics)" .
# :airsim		:topic		"Deep learning" .
# :airsim		:topic		"Extensibility" .
# :airsim		:topic		"Artificial intelligence" .
# :airsim		:topic		"Modular design" .
# :airsim		:topic		"Algorithm" .
# :airsim		:topic		"Augmented reality" .
# :airsim		:topic		"Hardware-in-the-loop simulation" .
# :airsim		:topic		"Component-based software engineering" .
# :airsim		:topic		"Experiment" .
# :airsim		:topic		"Sensor" .
# :airsim		:topic		"Real-time clock" .
# :airsim		:topic		"Application programming interface" .
# :airsim		:topic		"Global Positioning System" .
# :airsim		:topic		"Elegant degradation" .
# :airsim		:topic		"Stepping level" .
# :airsim		:topic		"MAVLink" .
# :airsim		:topic		"Real-time operating system" .
# :airsim		:topic		"Dynamical simulation" .
# :airsim		:citation	"Classical mechanics" .
# :airsim		:citation	"Introduction to fluid mechanics" .
# :airsim		:citation	"History of fluid mechanics" .
# :airsim		:citation	"Numerical methods for ordinary differential equations" .
# :airsim		:citation	"Design and use paradigms for Gazebo, an open-source multi-robot simulator" .
# :airsim		:citation	"The GGM03 Mean Earth Gravity Model from GRACE" .
# :airsim		:citation	"The Earth's Magnetism: An Introduction for Geologists" .
# :airsim		:citation	"An introduction to inertial navigation" .
# :airsim		:citation	"PIXHAWK: A system for autonomous flight using onboard computer vision" .
# :airsim		:citation	"Comprehensive Simulation of Quadrotor UAVs Using ROS and Gazebo" .
# :airsim		:citation	"Numerical Methods for Ordinary Differential Equations" .
# :airsim		:citation	"A survey of inverse reinforcement learning techniques" .
# :airsim		:citation	"A survey of inverse reinforcement learning techniques" .
# :airsim		:citation	"Reinforcement learning in robotics: A survey" .
# :airsim		:citation	"Real Shading in Unreal Engine 4 by" .
# :airsim		:citation	"A Stochastic Approach to Noise Modeling for Barometric Altimeters" .
# :airsim		:citation	"An Invitation to Imitation" .
# :airsim		:citation	"The US/UK World Magnetic Model for 2015-2020" .
# :airsim		:citation	"RotorS—A Modular Gazebo MAV Simulator Framework" .
# :airsim		:citation	"ROSflight: A lightweight, inexpensive MAV research and development tool" .
# :airsim		:citation	"Practical Meteorology: An Algebra-based Survey of Atmospheric Science" .
# :airsim		:citation	"A survey of transfer learning" .
# :airsim		:citation	"A First Course In Differential Equations" .
# :baidu		rdf:type	:Article .
# :baidu		:title		"An Auto-tuning Framework for Autonomous Vehicles" .
# :baidu		:topic		"Reinforcement learning" .
# :baidu		:topic		"Autonomous car" .
# :baidu		:topic		"Autonomous robot" .
# :baidu		:topic		"Simulation" .
# :baidu		:topic		"Mathematical optimization" .
# :baidu		:topic		"Self-tuning" .
# :baidu		:topic		"Algorithm" .
# :baidu		:topic		"Corner case" .
# :baidu		:topic		"Feature extraction" .
# :baidu		:topic		"Loss function" .
# :baidu		:topic		"Online and offline" .
# :baidu		:topic		"Machine learning" .
# :baidu		:topic		"Procedural generation" .
# :baidu		:topic		"Value network" .
# :baidu		:topic		"Long tail" .
# :baidu		:topic		"Scalability" .
# :baidu		:topic		"Tracer" .
# :baidu		:topic		"Auto-Tune" .
# :baidu		:topic		"Drug vehicle" .
# :baidu		:citation	"Efficient Training of Artificial Neural Networks for Autonomous Navigation" .
# :baidu		:citation	"Algorithms for Inverse Reinforcement Learning" .
# :baidu		:citation	"Proceedings of the twenty-first international conference on Machine learning" .
# :baidu		:citation	"Apprenticeship learning via inverse reinforcement learning" .
# :baidu		:citation	"Learning a similarity metric discriminatively, with application to face verification" .
# :baidu		:citation	"Maximum margin planning" .
# :baidu		:citation	"Maximum Entropy Inverse Reinforcement Learning" .
# :baidu		:citation	"Autonomous Driving in Urban Environments: Boss and the Urban Challenge" .
# :baidu		:citation	"Junior: The Stanford Entry in the Urban Challenge" .
# :baidu		:citation	"Optimal trajectory generation for dynamic street scenarios in a Frenét Frame" .
# :baidu		:citation	"Efficient Reductions for Imitation Learning" .
# :baidu		:citation	"A Reduction of Imitation Learning and Structured Prediction to No-Regret Online Learning" .
# :baidu		:citation	"Trajectory planning for Bertha — A local, continuous method" .
# :baidu		:citation	"End to End Learning for Self-Driving Cars" .
# :baidu		:citation	"A Fast Integrated Planning and Control Framework for Autonomous Driving via Imitation Learning" .
# :baidu		:citation	"Baidu Apollo EM Motion Planner" .
# :carla		rdf:type	:Article .
# :carla		:title		"CARLA: An Open Urban Driving Simulator" .
# :carla		:topic		"Driving simulator" .
# :carla		:topic		"Reinforcement learning" .
# :carla		:topic		"Autonomous car" .
# :carla		:topic		"Open-source software" .
# :carla		:topic		"Autonomous robot" .
# :carla		:topic		"Digital asset" .
# :carla		:topic		"Simulation" .
# :carla		:topic		"End-to-end principle" .
# :carla		:citation	"ALVINN: An Autonomous Land Vehicle in a Neural Network" .
# :carla		:citation	"Off-Road Obstacle Avoidance through End-to-End Learning" .
# :carla		:citation	"Learning from Demonstration for Autonomous Navigation in Complex Unstructured Terrain" .
# :carla		:citation	"Real-Time Camera Tracking: When is High Frame-Rate Best?" .
# :carla		:citation	"ImageNet classification with deep convolutional neural networks" .
# :carla		:citation	"Framework for Generation of Synthetic Ground Truth Data for Driver Assistance Applications" .
# :carla		:citation	"Robust PID Steering Control in Parameter Space for Highly Automated Driving" .
# :carla		:citation	"Adam: A Method for Stochastic Optimization" .
# :carla		:citation	"DeepDriving: Learning Affordance for Direct Perception in Autonomous Driving" .
# :carla		:citation	"Human-level control through deep reinforcement learning" .
# :carla		:citation	"Autonomous driving" .
# :carla		:citation	"High-fidelity simulation for evaluating robotic vision performance" .
# :carla		:citation	"A Benchmark and Simulator for UAV Tracking" .
# :carla		:citation	"Evaluating visual ADAS components on the COnGRATS dataset" .
# :carla		:citation	"Playing for Data: Ground Truth from Computer Games" .
# :carla		:citation	"Asynchronous Methods for Deep Reinforcement Learning" .
# :carla		:citation	"A Survey of Motion Planning and Control Techniques for Self-Driving Urban Vehicles" .
# :carla		:citation	"The SYNTHIA Dataset: A Large Collection of Synthetic Images for Semantic Segmentation of Urban Scenes" .
# :carla		:citation	"VirtualWorlds as Proxy for Multi-object Tracking Analysis" .
# :carla		:citation	"Benefit of large field-of-view cameras for visual odometry" .
# :carla		:citation	"Learning to Act by Predicting the Future" .
# :carla		:citation	"AutonoVi: Autonomous vehicle planning with dynamic maneuvers and traffic constraints" .
# :carla		:citation	"Playing for Benchmarks" .
# :carla		:citation	"Reinforcement Learning with Unsupervised Auxiliary Tasks" .
# :carla		:citation	"RefineNet: Multi-path Refinement Networks for High-Resolution Semantic Segmentation" .
# :carla		:citation	"Deep Reinforcement Learning that Matters" .
# :carla		:citation	"End-to-End Driving Via Conditional Imitation Learning" .
# :LGSVL		rdf:type	:Article .
# :LGSVL		:title		"LGSVL Simulator: A High Fidelity Simulator for Autonomous Driving" .
# :LGSVL		:topic		"Autonomous car" .
# :LGSVL		:topic		"Simulation" .
# :LGSVL		:topic		"Autonomous robot" .
# :LGSVL		:topic		"Open-source software" .
# :LGSVL		:topic		"Sensor" .
# :LGSVL		:topic		"End-to-end principle" .
# :LGSVL		:topic		"Algorithm" .
# :LGSVL		:citation	"ALVINN: An Autonomous Land Vehicle in a Neural Network" .
# :LGSVL		:citation	"Design and use paradigms for Gazebo, an open-source multi-robot simulator" .
# :LGSVL		:citation	"TORCS, The Open Racing Car Simulator" .
# :LGSVL		:citation	"Vision meets robotics: The KITTI dataset" .
# :LGSVL		:citation	"DeepDriving: Learning Affordance for Direct Perception in Autonomous Driving" .
# :LGSVL		:citation	"Playing for Data: Ground Truth from Computer Games" .
# :LGSVL		:citation	"Driving to safety: How many miles of driving would it take to demonstrate autonomous vehicle reliability?" .
# :LGSVL		:citation	"The Cityscapes Dataset for Semantic Urban Scene Understanding" .
# :LGSVL		:citation	"OpenAI Gym" .
# :LGSVL		:citation	"CARLA: An Open Urban Driving Simulator" .
# :LGSVL		:citation	"Driving in the Matrix: Can virtual worlds replace human-generated annotations for real world tasks?" .
# :LGSVL		:citation	"Playing for Benchmarks" .
# :LGSVL		:citation	"AirSim: High-Fidelity Visual and Physical Simulation for Autonomous Vehicles" .
# :LGSVL		:citation	"BDD100K: A Diverse Driving Video Database with Scalable Annotation Tooling" .
# :LGSVL		:citation	"Lanelet2: A high-definition map framework for the future of automated driving" .
# :LGSVL		:citation	"Cooperative Ramp Merging System: Agent-Based Modeling and Simulation Using Game Engine" .
# :LGSVL		:citation	"Scenic: a language for scenario specification and scene generation" .
# :LGSVL		:citation	"Scalability in Perception for Autonomous Driving: Waymo Open Dataset" .
# :LGSVL		:citation	"nuScenes: A Multimodal Dataset for Autonomous Driving" .
# :LGSVL		:citation	"Formal Scenario-Based Testing of Autonomous Vehicles: From Simulation to the Real World" .

# %%
"""
Now it's working you could think about structuring your KG with topics and citations as classes instead of Data Properties as currently:


:algorithm a   :topic 
:algorithm rdfs:label "Algorithm"
:sensor a   :topic 
:sensor rdfs:label "Sensor"

:airsim :hasTopic :algorithm
:airsim :hasTopic :sensor


etc

abstract
arxivId
authors
citationVelocity
citations
corpusId
doi
fieldsOfStudy
influentialCitationCount
isOpenAccess
isPublisherLicensed
is_open_access
is_publisher_licensed
numCitedBy
numCiting
paperId
references
title
topics
url
venue
year


"""
# print header
header = """
@prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
@prefix : <http://city.ac.uk/kg/lab4/> .

"""
ttl = header + "\n"

# iterate through dictionary
for key in results:
    # rdf:type
    paperId = results[key]['paperId']
    ttl += ":{}		rdf:type	:Article .\n".format(paperId)
    ttl += ":{}		:title		\"{}\" .\n".format(paperId, results[key]['title'])
    for topic in results[key]['topics'] :
        topic_label = topic['topic']
        topic_class = topic_label.lower()
        # :algorithm a   :topic 
        ttl += ":{}		a		:topic .\n".format(topic_class)
        # :algorithm rdfs:label "Algorithm" 
        ttl += ":{}		:rdfs:label		\"{}\" .\n".format(topic_class, topic_label)
        ttl += ":{}		:hasTopic		\"{}\" .\n".format(paperId, topic['topic'])
    for reference in results[key]['references'] :
        ttl += ":{}		:citation	\"{}\" .\n".format(paperId, reference['title'])
print(ttl)
# Out:
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix : <http://city.ac.uk/kg/lab4/> .
#
#
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		rdf:type	:Article .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:title		"AirSim: High-Fidelity Visual and Physical Simulation for Autonomous Vehicles" .
# :autonomous robot		a		:topic .
# :autonomous robot		:rdfs:label		"Autonomous robot" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:hasTopic		"Autonomous robot" .
# :physics engine		a		:topic .
# :physics engine		:rdfs:label		"Physics engine" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:hasTopic		"Physics engine" .
# :unreal development kit		a		:topic .
# :unreal development kit		:rdfs:label		"Unreal Development Kit" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:hasTopic		"Unreal Development Kit" .
# :physx		a		:topic .
# :physx		:rdfs:label		"PhysX" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:hasTopic		"PhysX" .
# :machine learning		a		:topic .
# :machine learning		:rdfs:label		"Machine learning" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:hasTopic		"Machine learning" .
# :reinforcement learning		a		:topic .
# :reinforcement learning		:rdfs:label		"Reinforcement learning" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:hasTopic		"Reinforcement learning" .
# :ray tracing (graphics)		a		:topic .
# :ray tracing (graphics)		:rdfs:label		"Ray tracing (graphics)" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:hasTopic		"Ray tracing (graphics)" .
# :deep learning		a		:topic .
# :deep learning		:rdfs:label		"Deep learning" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:hasTopic		"Deep learning" .
# :extensibility		a		:topic .
# :extensibility		:rdfs:label		"Extensibility" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:hasTopic		"Extensibility" .
# :artificial intelligence		a		:topic .
# :artificial intelligence		:rdfs:label		"Artificial intelligence" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:hasTopic		"Artificial intelligence" .
# :modular design		a		:topic .
# :modular design		:rdfs:label		"Modular design" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:hasTopic		"Modular design" .
# :algorithm		a		:topic .
# :algorithm		:rdfs:label		"Algorithm" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:hasTopic		"Algorithm" .
# :augmented reality		a		:topic .
# :augmented reality		:rdfs:label		"Augmented reality" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:hasTopic		"Augmented reality" .
# :hardware-in-the-loop simulation		a		:topic .
# :hardware-in-the-loop simulation		:rdfs:label		"Hardware-in-the-loop simulation" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:hasTopic		"Hardware-in-the-loop simulation" .
# :component-based software engineering		a		:topic .
# :component-based software engineering		:rdfs:label		"Component-based software engineering" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:hasTopic		"Component-based software engineering" .
# :experiment		a		:topic .
# :experiment		:rdfs:label		"Experiment" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:hasTopic		"Experiment" .
# :sensor		a		:topic .
# :sensor		:rdfs:label		"Sensor" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:hasTopic		"Sensor" .
# :real-time clock		a		:topic .
# :real-time clock		:rdfs:label		"Real-time clock" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:hasTopic		"Real-time clock" .
# :application programming interface		a		:topic .
# :application programming interface		:rdfs:label		"Application programming interface" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:hasTopic		"Application programming interface" .
# :global positioning system		a		:topic .
# :global positioning system		:rdfs:label		"Global Positioning System" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:hasTopic		"Global Positioning System" .
# :elegant degradation		a		:topic .
# :elegant degradation		:rdfs:label		"Elegant degradation" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:hasTopic		"Elegant degradation" .
# :stepping level		a		:topic .
# :stepping level		:rdfs:label		"Stepping level" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:hasTopic		"Stepping level" .
# :mavlink		a		:topic .
# :mavlink		:rdfs:label		"MAVLink" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:hasTopic		"MAVLink" .
# :real-time operating system		a		:topic .
# :real-time operating system		:rdfs:label		"Real-time operating system" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:hasTopic		"Real-time operating system" .
# :dynamical simulation		a		:topic .
# :dynamical simulation		:rdfs:label		"Dynamical simulation" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:hasTopic		"Dynamical simulation" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:citation	"Classical mechanics" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:citation	"Introduction to fluid mechanics" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:citation	"History of fluid mechanics" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:citation	"Numerical methods for ordinary differential equations" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:citation	"Design and use paradigms for Gazebo, an open-source multi-robot simulator" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:citation	"The GGM03 Mean Earth Gravity Model from GRACE" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:citation	"The Earth's Magnetism: An Introduction for Geologists" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:citation	"An introduction to inertial navigation" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:citation	"PIXHAWK: A system for autonomous flight using onboard computer vision" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:citation	"Comprehensive Simulation of Quadrotor UAVs Using ROS and Gazebo" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:citation	"Numerical Methods for Ordinary Differential Equations" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:citation	"A survey of inverse reinforcement learning techniques" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:citation	"A survey of inverse reinforcement learning techniques" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:citation	"Reinforcement learning in robotics: A survey" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:citation	"Real Shading in Unreal Engine 4 by" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:citation	"A Stochastic Approach to Noise Modeling for Barometric Altimeters" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:citation	"An Invitation to Imitation" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:citation	"The US/UK World Magnetic Model for 2015-2020" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:citation	"RotorS—A Modular Gazebo MAV Simulator Framework" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:citation	"ROSflight: A lightweight, inexpensive MAV research and development tool" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:citation	"Practical Meteorology: An Algebra-based Survey of Atmospheric Science" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:citation	"A survey of transfer learning" .
# :a20f3dfc9142b48b924e68ee22ba259a0d621bb2		:citation	"A First Course In Differential Equations" .
# :4592a123502a9e7bbd76d21c976a4ed17503df8c		rdf:type	:Article .
# :4592a123502a9e7bbd76d21c976a4ed17503df8c		:title		"An Auto-tuning Framework for Autonomous Vehicles" .
# :reinforcement learning		a		:topic .
# :reinforcement learning		:rdfs:label		"Reinforcement learning" .
# :4592a123502a9e7bbd76d21c976a4ed17503df8c		:hasTopic		"Reinforcement learning" .
# :autonomous car		a		:topic .
# :autonomous car		:rdfs:label		"Autonomous car" .
# :4592a123502a9e7bbd76d21c976a4ed17503df8c		:hasTopic		"Autonomous car" .
# :autonomous robot		a		:topic .
# :autonomous robot		:rdfs:label		"Autonomous robot" .
# :4592a123502a9e7bbd76d21c976a4ed17503df8c		:hasTopic		"Autonomous robot" .
# :simulation		a		:topic .
# :simulation		:rdfs:label		"Simulation" .
# :4592a123502a9e7bbd76d21c976a4ed17503df8c		:hasTopic		"Simulation" .
# :mathematical optimization		a		:topic .
# :mathematical optimization		:rdfs:label		"Mathematical optimization" .
# :4592a123502a9e7bbd76d21c976a4ed17503df8c		:hasTopic		"Mathematical optimization" .
# :self-tuning		a		:topic .
# :self-tuning		:rdfs:label		"Self-tuning" .
# :4592a123502a9e7bbd76d21c976a4ed17503df8c		:hasTopic		"Self-tuning" .
# :algorithm		a		:topic .
# :algorithm		:rdfs:label		"Algorithm" .
# :4592a123502a9e7bbd76d21c976a4ed17503df8c		:hasTopic		"Algorithm" .
# :corner case		a		:topic .
# :corner case		:rdfs:label		"Corner case" .
# :4592a123502a9e7bbd76d21c976a4ed17503df8c		:hasTopic		"Corner case" .
# :feature extraction		a		:topic .
# :feature extraction		:rdfs:label		"Feature extraction" .
# :4592a123502a9e7bbd76d21c976a4ed17503df8c		:hasTopic		"Feature extraction" .
# :loss function		a		:topic .
# :loss function		:rdfs:label		"Loss function" .
# :4592a123502a9e7bbd76d21c976a4ed17503df8c		:hasTopic		"Loss function" .
# :online and offline		a		:topic .
# :online and offline		:rdfs:label		"Online and offline" .
# :4592a123502a9e7bbd76d21c976a4ed17503df8c		:hasTopic		"Online and offline" .
# :machine learning		a		:topic .
# :machine learning		:rdfs:label		"Machine learning" .
# :4592a123502a9e7bbd76d21c976a4ed17503df8c		:hasTopic		"Machine learning" .
# :procedural generation		a		:topic .
# :procedural generation		:rdfs:label		"Procedural generation" .
# :4592a123502a9e7bbd76d21c976a4ed17503df8c		:hasTopic		"Procedural generation" .
# :value network		a		:topic .
# :value network		:rdfs:label		"Value network" .
# :4592a123502a9e7bbd76d21c976a4ed17503df8c		:hasTopic		"Value network" .
# :long tail		a		:topic .
# :long tail		:rdfs:label		"Long tail" .
# :4592a123502a9e7bbd76d21c976a4ed17503df8c		:hasTopic		"Long tail" .
# :scalability		a		:topic .
# :scalability		:rdfs:label		"Scalability" .
# :4592a123502a9e7bbd76d21c976a4ed17503df8c		:hasTopic		"Scalability" .
# :tracer		a		:topic .
# :tracer		:rdfs:label		"Tracer" .
# :4592a123502a9e7bbd76d21c976a4ed17503df8c		:hasTopic		"Tracer" .
# :auto-tune		a		:topic .
# :auto-tune		:rdfs:label		"Auto-Tune" .
# :4592a123502a9e7bbd76d21c976a4ed17503df8c		:hasTopic		"Auto-Tune" .
# :drug vehicle		a		:topic .
# :drug vehicle		:rdfs:label		"Drug vehicle" .
# :4592a123502a9e7bbd76d21c976a4ed17503df8c		:hasTopic		"Drug vehicle" .
# :4592a123502a9e7bbd76d21c976a4ed17503df8c		:citation	"Efficient Training of Artificial Neural Networks for Autonomous Navigation" .
# :4592a123502a9e7bbd76d21c976a4ed17503df8c		:citation	"Algorithms for Inverse Reinforcement Learning" .
# :4592a123502a9e7bbd76d21c976a4ed17503df8c		:citation	"Proceedings of the twenty-first international conference on Machine learning" .
# :4592a123502a9e7bbd76d21c976a4ed17503df8c		:citation	"Apprenticeship learning via inverse reinforcement learning" .
# :4592a123502a9e7bbd76d21c976a4ed17503df8c		:citation	"Learning a similarity metric discriminatively, with application to face verification" .
# :4592a123502a9e7bbd76d21c976a4ed17503df8c		:citation	"Maximum margin planning" .
# :4592a123502a9e7bbd76d21c976a4ed17503df8c		:citation	"Maximum Entropy Inverse Reinforcement Learning" .
# :4592a123502a9e7bbd76d21c976a4ed17503df8c		:citation	"Autonomous Driving in Urban Environments: Boss and the Urban Challenge" .
# :4592a123502a9e7bbd76d21c976a4ed17503df8c		:citation	"Junior: The Stanford Entry in the Urban Challenge" .
# :4592a123502a9e7bbd76d21c976a4ed17503df8c		:citation	"Optimal trajectory generation for dynamic street scenarios in a Frenét Frame" .
# :4592a123502a9e7bbd76d21c976a4ed17503df8c		:citation	"Efficient Reductions for Imitation Learning" .
# :4592a123502a9e7bbd76d21c976a4ed17503df8c		:citation	"A Reduction of Imitation Learning and Structured Prediction to No-Regret Online Learning" .
# :4592a123502a9e7bbd76d21c976a4ed17503df8c		:citation	"Trajectory planning for Bertha — A local, continuous method" .
# :4592a123502a9e7bbd76d21c976a4ed17503df8c		:citation	"End to End Learning for Self-Driving Cars" .
# :4592a123502a9e7bbd76d21c976a4ed17503df8c		:citation	"A Fast Integrated Planning and Control Framework for Autonomous Driving via Imitation Learning" .
# :4592a123502a9e7bbd76d21c976a4ed17503df8c		:citation	"Baidu Apollo EM Motion Planner" .
# :1b7ef1a7df32d8d38efbb7aca9a9b2468d0da224		rdf:type	:Article .
# :1b7ef1a7df32d8d38efbb7aca9a9b2468d0da224		:title		"CARLA: An Open Urban Driving Simulator" .
# :driving simulator		a		:topic .
# :driving simulator		:rdfs:label		"Driving simulator" .
# :1b7ef1a7df32d8d38efbb7aca9a9b2468d0da224		:hasTopic		"Driving simulator" .
# :reinforcement learning		a		:topic .
# :reinforcement learning		:rdfs:label		"Reinforcement learning" .
# :1b7ef1a7df32d8d38efbb7aca9a9b2468d0da224		:hasTopic		"Reinforcement learning" .
# :autonomous car		a		:topic .
# :autonomous car		:rdfs:label		"Autonomous car" .
# :1b7ef1a7df32d8d38efbb7aca9a9b2468d0da224		:hasTopic		"Autonomous car" .
# :open-source software		a		:topic .
# :open-source software		:rdfs:label		"Open-source software" .
# :1b7ef1a7df32d8d38efbb7aca9a9b2468d0da224		:hasTopic		"Open-source software" .
# :autonomous robot		a		:topic .
# :autonomous robot		:rdfs:label		"Autonomous robot" .
# :1b7ef1a7df32d8d38efbb7aca9a9b2468d0da224		:hasTopic		"Autonomous robot" .
# :digital asset		a		:topic .
# :digital asset		:rdfs:label		"Digital asset" .
# :1b7ef1a7df32d8d38efbb7aca9a9b2468d0da224		:hasTopic		"Digital asset" .
# :simulation		a		:topic .
# :simulation		:rdfs:label		"Simulation" .
# :1b7ef1a7df32d8d38efbb7aca9a9b2468d0da224		:hasTopic		"Simulation" .
# :end-to-end principle		a		:topic .
# :end-to-end principle		:rdfs:label		"End-to-end principle" .
# :1b7ef1a7df32d8d38efbb7aca9a9b2468d0da224		:hasTopic		"End-to-end principle" .
# :1b7ef1a7df32d8d38efbb7aca9a9b2468d0da224		:citation	"ALVINN: An Autonomous Land Vehicle in a Neural Network" .
# :1b7ef1a7df32d8d38efbb7aca9a9b2468d0da224		:citation	"Off-Road Obstacle Avoidance through End-to-End Learning" .
# :1b7ef1a7df32d8d38efbb7aca9a9b2468d0da224		:citation	"Learning from Demonstration for Autonomous Navigation in Complex Unstructured Terrain" .
# :1b7ef1a7df32d8d38efbb7aca9a9b2468d0da224		:citation	"Real-Time Camera Tracking: When is High Frame-Rate Best?" .
# :1b7ef1a7df32d8d38efbb7aca9a9b2468d0da224		:citation	"ImageNet classification with deep convolutional neural networks" .
# :1b7ef1a7df32d8d38efbb7aca9a9b2468d0da224		:citation	"Framework for Generation of Synthetic Ground Truth Data for Driver Assistance Applications" .
# :1b7ef1a7df32d8d38efbb7aca9a9b2468d0da224		:citation	"Robust PID Steering Control in Parameter Space for Highly Automated Driving" .
# :1b7ef1a7df32d8d38efbb7aca9a9b2468d0da224		:citation	"Adam: A Method for Stochastic Optimization" .
# :1b7ef1a7df32d8d38efbb7aca9a9b2468d0da224		:citation	"DeepDriving: Learning Affordance for Direct Perception in Autonomous Driving" .
# :1b7ef1a7df32d8d38efbb7aca9a9b2468d0da224		:citation	"Human-level control through deep reinforcement learning" .
# :1b7ef1a7df32d8d38efbb7aca9a9b2468d0da224		:citation	"Autonomous driving" .
# :1b7ef1a7df32d8d38efbb7aca9a9b2468d0da224		:citation	"High-fidelity simulation for evaluating robotic vision performance" .
# :1b7ef1a7df32d8d38efbb7aca9a9b2468d0da224		:citation	"A Benchmark and Simulator for UAV Tracking" .
# :1b7ef1a7df32d8d38efbb7aca9a9b2468d0da224		:citation	"Evaluating visual ADAS components on the COnGRATS dataset" .
# :1b7ef1a7df32d8d38efbb7aca9a9b2468d0da224		:citation	"Playing for Data: Ground Truth from Computer Games" .
# :1b7ef1a7df32d8d38efbb7aca9a9b2468d0da224		:citation	"Asynchronous Methods for Deep Reinforcement Learning" .
# :1b7ef1a7df32d8d38efbb7aca9a9b2468d0da224		:citation	"A Survey of Motion Planning and Control Techniques for Self-Driving Urban Vehicles" .
# :1b7ef1a7df32d8d38efbb7aca9a9b2468d0da224		:citation	"The SYNTHIA Dataset: A Large Collection of Synthetic Images for Semantic Segmentation of Urban Scenes" .
# :1b7ef1a7df32d8d38efbb7aca9a9b2468d0da224		:citation	"VirtualWorlds as Proxy for Multi-object Tracking Analysis" .
# :1b7ef1a7df32d8d38efbb7aca9a9b2468d0da224		:citation	"Benefit of large field-of-view cameras for visual odometry" .
# :1b7ef1a7df32d8d38efbb7aca9a9b2468d0da224		:citation	"Learning to Act by Predicting the Future" .
# :1b7ef1a7df32d8d38efbb7aca9a9b2468d0da224		:citation	"AutonoVi: Autonomous vehicle planning with dynamic maneuvers and traffic constraints" .
# :1b7ef1a7df32d8d38efbb7aca9a9b2468d0da224		:citation	"Playing for Benchmarks" .
# :1b7ef1a7df32d8d38efbb7aca9a9b2468d0da224		:citation	"Reinforcement Learning with Unsupervised Auxiliary Tasks" .
# :1b7ef1a7df32d8d38efbb7aca9a9b2468d0da224		:citation	"RefineNet: Multi-path Refinement Networks for High-Resolution Semantic Segmentation" .
# :1b7ef1a7df32d8d38efbb7aca9a9b2468d0da224		:citation	"Deep Reinforcement Learning that Matters" .
# :1b7ef1a7df32d8d38efbb7aca9a9b2468d0da224		:citation	"End-to-End Driving Via Conditional Imitation Learning" .
# :65b58efdd4c04bb501244a8f825b28dcba788b60		rdf:type	:Article .
# :65b58efdd4c04bb501244a8f825b28dcba788b60		:title		"LGSVL Simulator: A High Fidelity Simulator for Autonomous Driving" .
# :autonomous car		a		:topic .
# :autonomous car		:rdfs:label		"Autonomous car" .
# :65b58efdd4c04bb501244a8f825b28dcba788b60		:hasTopic		"Autonomous car" .
# :simulation		a		:topic .
# :simulation		:rdfs:label		"Simulation" .
# :65b58efdd4c04bb501244a8f825b28dcba788b60		:hasTopic		"Simulation" .
# :autonomous robot		a		:topic .
# :autonomous robot		:rdfs:label		"Autonomous robot" .
# :65b58efdd4c04bb501244a8f825b28dcba788b60		:hasTopic		"Autonomous robot" .
# :open-source software		a		:topic .
# :open-source software		:rdfs:label		"Open-source software" .
# :65b58efdd4c04bb501244a8f825b28dcba788b60		:hasTopic		"Open-source software" .
# :sensor		a		:topic .
# :sensor		:rdfs:label		"Sensor" .
# :65b58efdd4c04bb501244a8f825b28dcba788b60		:hasTopic		"Sensor" .
# :end-to-end principle		a		:topic .
# :end-to-end principle		:rdfs:label		"End-to-end principle" .
# :65b58efdd4c04bb501244a8f825b28dcba788b60		:hasTopic		"End-to-end principle" .
# :algorithm		a		:topic .
# :algorithm		:rdfs:label		"Algorithm" .
# :65b58efdd4c04bb501244a8f825b28dcba788b60		:hasTopic		"Algorithm" .
# :65b58efdd4c04bb501244a8f825b28dcba788b60		:citation	"ALVINN: An Autonomous Land Vehicle in a Neural Network" .
# :65b58efdd4c04bb501244a8f825b28dcba788b60		:citation	"Design and use paradigms for Gazebo, an open-source multi-robot simulator" .
# :65b58efdd4c04bb501244a8f825b28dcba788b60		:citation	"TORCS, The Open Racing Car Simulator" .
# :65b58efdd4c04bb501244a8f825b28dcba788b60		:citation	"Vision meets robotics: The KITTI dataset" .
# :65b58efdd4c04bb501244a8f825b28dcba788b60		:citation	"DeepDriving: Learning Affordance for Direct Perception in Autonomous Driving" .
# :65b58efdd4c04bb501244a8f825b28dcba788b60		:citation	"Playing for Data: Ground Truth from Computer Games" .
# :65b58efdd4c04bb501244a8f825b28dcba788b60		:citation	"Driving to safety: How many miles of driving would it take to demonstrate autonomous vehicle reliability?" .
# :65b58efdd4c04bb501244a8f825b28dcba788b60		:citation	"The Cityscapes Dataset for Semantic Urban Scene Understanding" .
# :65b58efdd4c04bb501244a8f825b28dcba788b60		:citation	"OpenAI Gym" .
# :65b58efdd4c04bb501244a8f825b28dcba788b60		:citation	"CARLA: An Open Urban Driving Simulator" .
# :65b58efdd4c04bb501244a8f825b28dcba788b60		:citation	"Driving in the Matrix: Can virtual worlds replace human-generated annotations for real world tasks?" .
# :65b58efdd4c04bb501244a8f825b28dcba788b60		:citation	"Playing for Benchmarks" .
# :65b58efdd4c04bb501244a8f825b28dcba788b60		:citation	"AirSim: High-Fidelity Visual and Physical Simulation for Autonomous Vehicles" .
# :65b58efdd4c04bb501244a8f825b28dcba788b60		:citation	"BDD100K: A Diverse Driving Video Database with Scalable Annotation Tooling" .
# :65b58efdd4c04bb501244a8f825b28dcba788b60		:citation	"Lanelet2: A high-definition map framework for the future of automated driving" .
# :65b58efdd4c04bb501244a8f825b28dcba788b60		:citation	"Cooperative Ramp Merging System: Agent-Based Modeling and Simulation Using Game Engine" .
# :65b58efdd4c04bb501244a8f825b28dcba788b60		:citation	"Scenic: a language for scenario specification and scene generation" .
# :65b58efdd4c04bb501244a8f825b28dcba788b60		:citation	"Scalability in Perception for Autonomous Driving: Waymo Open Dataset" .
# :65b58efdd4c04bb501244a8f825b28dcba788b60		:citation	"nuScenes: A Multimodal Dataset for Autonomous Driving" .
# :65b58efdd4c04bb501244a8f825b28dcba788b60		:citation	"Formal Scenario-Based Testing of Autonomous Vehicles: From Simulation to the Real World" .

# %%
f = open('av.ttl', 'w')
f.write(ttl)
f.close()

# %%
# TODO - write queries
# 1. Common topics
# 2. Common references
# 2.1 Appearing in at least two articles
# 2.2 Appearing in all articles
# We would like insights similar to:
# https://www.citationtree.org/tree?id=10.1007/978-3-319-67361-5_40
# https://github.com/city-knowledge-graphs/python/blob/main/lab4/lab4.ttl
